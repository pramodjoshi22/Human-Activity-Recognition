# %%
# libraries

import pandas as pd
import numpy as np
import os
from google.colab import drive
from sklearn import neighbors

# %%
drive.mount('/content/drive')
# %cd '/content/drive/My Drive/CS3244 Team37/HAPT Data Set'
# Out:
# Mounted at /content/drive
# [Errno 2] No such file or directory: '/content/drive/My Drive/CS3244 Team37/HAPT Data Set'
# /content

# %%
def knn = neighbors.KNeighborsClassifier()
# Out:
#   File "<ipython-input-5-01113fabc896>", line 1
#     def knn = neighbors.KNeighborsClassifier()
#             ^
# SyntaxError: invalid syntax
